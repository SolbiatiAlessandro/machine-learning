# %% [markdown]
# <a href="https://www.kaggle.com/code/alessandrosolbiati/zero-shot-learning-vmware-text-embedding?scriptVersionId=222083141" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/vmware-zero-shot-information-retrieval/sample_submission.csv
# /kaggle/input/vmware-zero-shot-information-retrieval/vmware_ir_content.csv
# /kaggle/input/vmware-zero-shot-information-retrieval/test.csv

# %%
hyperparameters = {
    'chunk_size_characters': 400,
    'chunk_size_padding': 50,
}

# %% [markdown]
# # Chunk Documents

# %%
test = pd.read_csv("/kaggle/input/vmware-zero-shot-information-retrieval/test.csv")

#sorted(list(test.Query), key=len)[1000:1100]

# %%
pp = filter(lambda x: 'network' in x, list(test.Query))
network_queries = list(pp)
network_queries
# Out:
# ['what is network virtualization',
#  'what is cloud networking',
#  'what is virtual network',
#  'what is a virtual network',
#  'what is network configuration',
#  'what is network access control',
#  'postgresql replication is not in progress. verify if postgresql server is running on the passive node and that the passive node is reachable on the vcenter ha network.',
#  'what is network automation',
#  'failed to get management network information. verify if management interface (nic0) is configured correctly and is reachable, and verify if correct dns mapping is provided for forward and reverse hostname lookup.',
#  'this virtual machine might have been moved or copied. in order to configure certain management and networking features, vmware esx needs to know if this virtual machine was moved or copied. if you don\'t know, answer "i copied it".',
#  'what is intent based networking',
#  'what is the core component of intent-based networking?',
#  'what is enterprise network',
#  'how to configure a nat network in vmware workstation',
#  'what is storage area network',
#  'how do servers connect to the network in a virtual environment',
#  'what is virtualization in networking',
#  'what is an enterprise network',
#  'what is virtual networking',
#  'what is network convergence',
#  'what is cloud network',
#  'what is converged network',
#  'what is convergence in networking',
#  'what is software defined networking',
#  'what is enterprise networking',
#  'the vsphere ha agent on this host cannot reach some of the management network addresses of other hosts, and ha may not be able to restart vms if a host failure occurs:',
#  'what is a cloud network',
#  'what is a converged network',
#  'what is intent-based networking',
#  'the feature you are trying to use is on a network resource that is unavailable when installing',
#  'what is micro segmentation in networking',
#  'what is the purpose of having a converged network?',
#  'what is container networking',
#  'how does software defined networking work',
#  'what is network infrastructure security',
#  'what is cloud in computer network',
#  'what is cloud in networking',
#  'what is network virtualization in cloud computing',
#  'what is san in networking',
#  'what is the core component of internet-based networking',
#  'what is network security',
#  'how storage area network works',
#  'what is a federated network',
#  'what are virtual networks',
#  'what is network infrastructure',
#  'how to disable vmware network adapter windows 10',
#  'the vsphere ha agent on this host cannot reach some of the management network addresses of other hosts, and ha may not be able to restart vms if a host failure occurs',
#  'how does network access control work',
#  'how to connect virtual machine to physical network',
#  'how possible are the traditional separate data, telephone, and video networks be converged together into one platform?',
#  'what is a network cloud',
#  'how to remove vmware network adapter',
#  'what is the core component of intent-based networking',
#  'what is kubernetes networking',
#  'what is a benefit of using vsphere distributed switches in a vsan network?',
#  'what is the maximum number of hosts per vnetwork distributed switch?',
#  'what is configuration in networking',
#  'what is a san in networking',
#  'what is meant by a virtual network',
#  'what is the purpose of having a converged network']

# %%
import pandas as pd
content = pd.read_csv("/kaggle/input/vmware-zero-shot-information-retrieval/vmware_ir_content.csv")
len(content)
# Out:
# 323963

# %%
content = content[content.raw_text.fillna("").apply(lambda x: 'network' in x)]
len(content)
# Out:
# 62371

# %%
content['raw_text'].str.len().sum() # 750M
# num of chunks 750M / 20 = 30M
# Out:
# 275640277

# %%
sampled_content = content.sample(frac=0.01)
len(sampled_content)
# Out:
# 624

# %%
from dataclasses import dataclass

chunk_size = hyperparameters['chunk_size_characters']
padding = hyperparameters['chunk_size_padding']
CHUNK_MAX_LENGTH = chunk_size + 2 * padding

def chunkify(document):
    ix, chunks = 0, []
    while ix < len(document):
        chunk_start = ix 
        chunk_end   = ix + padding + chunk_size + padding
        chunks.append(document[chunk_start:chunk_end])
        ix = ix + padding + chunk_size
    return chunks

@dataclass
class Chunk:
    document_id: int
    chunk_data: str

chunks = [] # id: chunk
for ix, (k,v) in enumerate(list(content['raw_text'].fillna("").items())):

    kchunks = chunkify(v)
    for kchunk in kchunks:
        if "network" in kchunk:
            chunks.append(Chunk(document_id=k, chunk_data=kchunk))
    if ix % 10000 == 0:
        print(f"id: {k}, passage length: {len(v)}, number of chunks: {len(kchunks)}")
print(len(chunks))
# Out:
# id: 3, passage length: 3918, number of chunks: 9
# id: 49212, passage length: 1915, number of chunks: 5
# id: 104920, passage length: 1252, number of chunks: 3
# id: 157021, passage length: 3230, number of chunks: 8
# id: 208526, passage length: 3191, number of chunks: 8
# id: 259705, passage length: 1762, number of chunks: 4
# id: 311489, passage length: 4123, number of chunks: 10
# 151101

# %%
c1 = chunks[0].chunk_data
c2 = chunks[30].chunk_data
c1, c2

# %% [markdown]
# # Text Embedding model

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Each input text should start with "query: " or "passage: ".
# For tasks other than retrieval, you can simply use the "query: " prefix.
input_texts = [f'query: {chunks[0].chunk_data}',
               f'query: {chunks[-10].chunk_data}',
               f'query: {chunks[1].chunk_data}',
               f'query: {chunks[-11].chunk_data}']
input_texts

# %%
import torch.nn.functional as F

from torch import Tensor
from transformers import AutoTokenizer, AutoModel

tokenizer = AutoTokenizer.from_pretrained('intfloat/e5-small-v2')
model = AutoModel.from_pretrained('intfloat/e5-small-v2').to(device)
#  model alone on GPU T4 is 243MiB /  15360MiB 


def average_pool(last_hidden_states: Tensor,
                 attention_mask: Tensor) -> Tensor:
    last_hidden = last_hidden_states.masked_fill(~attention_mask[..., None].bool(), 0.0)
    return last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]

def model_predict(input_texts: list[str], model=model, tokenizer=tokenizer):
    # Tokenize the input texts
    batch_dict = tokenizer(input_texts, max_length=CHUNK_MAX_LENGTH, padding=True, truncation=True, return_tensors='pt')
    batch_dict = {k: v.to(device) for k, v in batch_dict.items()}
    with torch.no_grad():
        outputs = model(**batch_dict)
        embeddings = average_pool(outputs.last_hidden_state, batch_dict['attention_mask'])
        # normalize embeddings
        embeddings = F.normalize(embeddings, p=2, dim=1)
    return embeddings, batch_dict

# %%
embeddings, _ = model_predict(input_texts)
scores = (embeddings[:2] @ embeddings[2:].T) * 100
print(scores.tolist())

# %%
chunked_corpus = [f"query: {chunk.chunk_data}" for chunk in chunks][:3000]
len(chunked_corpus)

# 1315MiB /  15360MiB after first inference of 300
# 2709MiB /  15360MiB inference of 600
# 13913MiB /  15360MiB  inference for 3000 chunks, takes 3 seconds (3 * 10^3 seconds)

# total number of chunks is 3*10^7 = 10^4 seconds to embed them all = 3 hours
# I have two GPUs and I can do it in parallel and is going to take 1 hour

# 3000 embeddings are 3000 * 348 emb size * 4bytes = 1MB in memory  = 10^6
# I have 10GB memory 10^10 , can hold 3 * 10^3 * 10^4 = 3 10^7 embeddings

# %%
sum([len(c) for c in chunked_corpus])

# %%
from time import time
start_time = time()
embeddings = model_predict(chunked_corpus)
end_time = time()
print(f"Model inference for {len(chunked_corpus)} chunks: {end_time - start_time:.2f} seconds")

# %%
print(embeddings.shape)
end_time = time()
print(f"Model inference for {len(chunked_corpus)} chunks: {end_time - start_time:.2f} seconds")

# %%
# !nvidia-smi
# Out:
# Wed Feb 12 01:48:59 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   62C    P0             30W /   70W |     479MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
torch.cuda.empty_cache()

# %%
embeddings.shape

# %%
from torch.utils.data import Dataset, DataLoader


class ChunkTextDataset(Dataset):
    def __init__(self, chunks: list[Chunk]):
        # Prepend "query: " to each chunk's text.
        self.texts = [f"query: {chunk.chunk_data}" for chunk in chunks]

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        return self.texts[idx]


dataset = ChunkTextDataset(chunks)
dataloader = DataLoader(dataset, batch_size=1000, shuffle=False)

# %%
torch.cuda.empty_cache()

# %%
all_embeddings = []
import gc
    
# Disable gradients for inference.
with torch.no_grad():
    for batch in dataloader:

        from time import time
        start_time = time()

        # Each 'batch' is a list of strings (already with "query: " prepended).
        embeddings, batch_dict = model_predict(batch)  # Assume this returns a tensor of shape [batch_size, embedding_dim]

        end_time = time()
        
        torch.cuda.empty_cache()
        print(f"Processed batch of {len(batch)} chunks, {end_time - start_time:.2f} seconds")

        # Move embeddings to CPU (if they are on GPU) and append.
        all_embeddings.append(embeddings.cpu())

        # Clean up GPU memory:
        del batch_dict
        del embeddings
        del batch
        torch.cuda.empty_cache()
        gc.collect()
              
        

        
        
# Concatenate all the batch embeddings into a single tensor.
all_embeddings = torch.cat(all_embeddings, dim=0)
# Out:
# Processed batch of 1000 chunks, 0.24 seconds
# Processed batch of 1000 chunks, 0.24 seconds
# Processed batch of 1000 chunks, 0.24 seconds
# Processed batch of 1000 chunks, 0.23 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.27 seconds
# Processed batch of 1000 chunks, 0.35 seconds
# Processed batch of 1000 chunks, 0.35 seconds
# Processed batch of 1000 chunks, 0.36 seconds
# Processed batch of 1000 chunks, 0.28 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.38 seconds
# Processed batch of 1000 chunks, 0.35 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.40 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.34 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.28 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.37 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.34 seconds
# Processed batch of 1000 chunks, 0.36 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.29 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.38 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.36 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.34 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.29 seconds
# Processed batch of 1000 chunks, 0.29 seconds
# Processed batch of 1000 chunks, 0.34 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.36 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.34 seconds
# Processed batch of 1000 chunks, 0.36 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.29 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.35 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.38 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.35 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.34 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.34 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.29 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.35 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.29 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.36 seconds
# Processed batch of 1000 chunks, 0.26 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.29 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.28 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.34 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.36 seconds
# Processed batch of 1000 chunks, 0.28 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.29 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.29 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.35 seconds
# Processed batch of 1000 chunks, 0.31 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 1000 chunks, 0.30 seconds
# Processed batch of 1000 chunks, 0.28 seconds
# Processed batch of 1000 chunks, 0.34 seconds
# Processed batch of 1000 chunks, 0.29 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.32 seconds
# Processed batch of 1000 chunks, 0.33 seconds
# Processed batch of 101 chunks, 0.29 seconds

# %%
len(chunks)

import pickle



# Save the chunks list to disk
with open('/kaggle/working/chunks151101_11_Feb_A__(network).pkl', 'wb') as f:
    pickle.dump(chunks, f)

# %%
all_embeddings.shape

np.save('/kaggle/working/embeddings151101x384_11_Feb_A__(network).npy', all_embeddings)

# %%
embeddings = all_embeddings

# %% [markdown]
# # Indexing

# %%
# !pip install faiss-gpu
# Out:
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 20.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2

# %%
embeddings.shape
# Out:
# torch.Size([151101, 384])

# %%
import faiss

# Get the dimensionality of your embeddings.


embeddings_np = embeddings.cpu().detach().numpy().astype('float32')

dimension = embeddings.shape[1]

# Create a FAISS index. For example, use IndexFlatL2 for exact L2 (Euclidean) distance search:
index = faiss.IndexFlatL2(dimension)
# For inner product similarity, you could use:
# index = faiss.IndexFlatIP(dimension)

# Add your embeddings to the index.
index.add(embeddings_np)
print(f"Number of embeddings indexed: {index.ntotal}")
# Out:
# Number of embeddings indexed: 151101

# %%
query_embeddings, _ = model_predict([f"query: {query}" for query in network_queries])

# %%
query_embeddings.shape
# Out:
# torch.Size([60, 384])

# %%
query_np = query_embeddings.cpu().detach().numpy().astype('float32')

# %%
query_np.shape
# Out:
# (60, 384)

# %%
distances, indexes = index.search(query_np, 100)

# %%
distances.shape, indexes.shape
# Out:
# ((60, 100), (60, 100))

# %%
indexes.map(lambda ix: chunks[ix].document_id)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-034fc606c979> in <cell line: 1>()
# ----> 1 indexes.map(lambda ix: chunks[ix].document_id)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'map'

# %%
import numpy as np

# Create a vectorized function that extracts the document_id
get_doc_id = np.vectorize(lambda ix: chunks[ix].document_id)
document_ids = get_doc_id(indexes)

# %%
top_5_document_ids = {}
for query_ix, d in enumerate(document_ids):
    res = []
    ix = 0
    while len(res) <= 5:
        doc = d[ix]
        if doc not in res:
            res.append(doc)
        ix += 1
    top_5_document_ids[query_ix] = res

# %%
query_predictions = {}
top_5_document_ids
for query_ix, dix in top_5_document_ids.items():
    query_predictions[query_ix] = {'documents': list(map(lambda ix: content.loc[ix].raw_text[:100], dix)), 
                                   'query': network_queries[query_ix]}

# %%
for k, v in query_predictions.items():
    print(f"Query: {v['query']}")
    for d in v['documents']:
        print(d.replace("\n", " "))
    print('\n\n')
# Out:
# Query: what is network virtualization
# What is Network Virtualization? | VMware Glossary Network Virtualization What is network virtualizat
# What Is Network Virtualization? | Network and Security Virtualization | VMware Post to Facebook Shar
# What is Virtual Networking? | VMware Glossary Virtual Networking What is virtual networking? Get the
# What is virtualization technology & virtual machine? | VMware Solutions by Category Virtualization W
# What is Desktop Virtualization? | VMware Glossary Desktop Virtualization What is Desktop Virtualizat
# What is Network Functions Virtualization (NFV)? | VMware Glossary Network Functions Virtualization (
#
#
#
# Query: what is cloud networking
# What is Cloud Networking? | VMware Glossary Cloud Networking What is cloud networking? Cloud network
# What is a Cloud Server? | VMware Glossary Cloud Server What is a cloud server? A cloud server is a p
# What is Enterprise Networking? | VMware Glossary Enterprise Networking What is enterprise networking
# What is Hybrid Cloud Networking? | VMware Glossary Hybrid Cloud Networking What is a hybrid cloud ne
# What is the Cloud | VMware Glossary Cloud What is the Cloud? The cloud is general term used to descr
# What is Cloud Computing Infrastructure? | VMware Glossary Cloud Computing Infrastructure What is Clo
#
#
#
# Query: what is virtual network
# What is Virtual Networking? | VMware Glossary Virtual Networking What is virtual networking? Get the
# What is Network Virtualization? | VMware Glossary Network Virtualization What is network virtualizat
# The Virtual Cloud Network Introduction | Network and Security Virtualization | VMware Post to Facebo
# What is Enterprise Networking? | VMware Glossary Enterprise Networking What is enterprise networking
# What Is Network Virtualization? | Network and Security Virtualization | VMware Post to Facebook Shar
# Introducing the Virtual Cloud Network - Power of Partnership Share on:Share on Twitter Share on Link
#
#
#
# Query: what is a virtual network
# What is Virtual Networking? | VMware Glossary Virtual Networking What is virtual networking? Get the
# What is Network Virtualization? | VMware Glossary Network Virtualization What is network virtualizat
# The Virtual Cloud Network Introduction | Network and Security Virtualization | VMware Post to Facebo
# What is Enterprise Networking? | VMware Glossary Enterprise Networking What is enterprise networking
# What Is Network Virtualization? | Network and Security Virtualization | VMware Post to Facebook Shar
# What is Cloud Networking? | VMware Glossary Cloud Networking What is cloud networking? Cloud network
#
#
#
# Query: what is network configuration
# What is Network Configuration? | VMware Glossary Network Configuration What is network configuration
# Network Configuration Manager network container.
# Network Configuration Manager network container.
# To migrate the network traffic of distributed port groups to a LAG, you create a new LAG. Procedure
# The latest release of Unified Access Gateway does not accept netmask or prefix and default gateway s
# The latest release of Unified Access Gateway does not accept netmask or prefix and default gateway s
#
#
#
# Query: what is network access control
# What is Network Access Control? | VMware Glossary Network Access Control What is network access cont
# What is Network Infrastructure Security? | VMware Glossary Network Infrastructure Security What is N
# What is Network Security? | VMware Glossary Network Security What is network security? Network secur
# Network Configuration Manager network container.
# Network Configuration Manager network container.
# What is Network Configuration Manager? An automated compliance, change and configuration management
#
#
#
# Query: postgresql replication is not in progress. verify if postgresql server is running on the passive node and that the passive node is reachable on the vcenter ha network.
# VMware Cloud Director maintains synchronous streaming replication between the nodes. If a standby no
# Ensure that your system is prepared for vCenter Server upgrade by verifying compatibility and comple
# Ensure that your system is prepared for vCenter Server upgrade by verifying compatibility and comple
# For a vCenter HA cluster to be healthy, each of the Active, Passive, and Witness nodes must be fully
# For a vCenter HA cluster to be healthy, each of the Active, Passive, and Witness nodes must be fully
# For a vCenter HA cluster to be healthy, each of the Active, Passive, and Witness nodes must be fully
#
#
#
# Query: what is network automation
# What is Network Automation? | VMware Glossary Network Automation What is network automation? Network
# Network Automation Solutions | VMware Solutions by Category Network Automation Network Automation So
# What is Cloud Automation? | VMware Glossary Cloud Automation What is cloud automation? Cloud automat
# How Network Automation Relieves Network Engineers During Pandemic Post to Facebook Share on LinkedIn
# What is Network Security? | VMware Glossary Network Security What is network security? Network secur
# How to Implement and Apply Network Automation Enterprise-wide Share on:Share on Twitter Share on Lin
#
#
#
# Query: failed to get management network information. verify if management interface (nic0) is configured correctly and is reachable, and verify if correct dns mapping is provided for forward and reverse hostname lookup.
# "Failed to get management network information." error configuring vCenter HA (2147932) | VMware KB "
# "Hostname was not updated via dns reverse-lookup" configuration failure during initial power up of a
# Creating a report in VMware vCenter Chargeback fails with the error: Error in generating report with
# VMware ESXi 5.1 hostname remains blank when deployed using Auto Deploy (2068827) | VMware KB VMware
# Troubleshooting virtual machine network connection issues (1003893) | VMware KB Troubleshooting virt
# VCHA deployment fails with error: Verify if management interface (nic0) is configured correctly and
#
#
#
# Query: this virtual machine might have been moved or copied. in order to configure certain management and networking features, vmware esx needs to know if this virtual machine was moved or copied. if you don't know, answer "i copied it".
# Managing Virtual Machine questions with PowerCLI - VMware PowerCLI Blog Share on:Share on Twitter Sh
# Answering a virtual machine related question from the command line (1026835) | VMware KB Answering a
# vCenter Server 5.5 Update 2 | 09 SEP 2014 | Build 2001466 vCenter Server 5.5 Update 2 installation P
# Restarting of the VMware Horizon View virtual machines results in the error: This virtual machine mi
# Virtual Machine Messages are automatically dismissed after 4 minutes (2113542) | VMware KB Virtual M
# VMware ESXi 5.0, Patch ESXi500-201212201-UG: Updates VMware ESXi 5.0 esx-base vib (2033753) | VMware
#
#
#
# Query: what is intent based networking
# What is Intent-Based Networking (IBN)? | VMware Glossary Intent-based Networking What is intent-base
# What is Network Automation? | VMware Glossary Network Automation What is network automation? Network
# An intent is a desired property of your network. An intent can describe a business policy or an arch
# Provider networks map to physical networks in your data center, and their networking functions are p
# Provider networks map to physical networks in your data center, and their networking functions are p
# Provider networks map to physical networks in your data center, and their networking functions are p
#
#
#
# Query: what is the core component of intent-based networking?
# What is Intent-Based Networking (IBN)? | VMware Glossary Intent-based Networking What is intent-base
# What is Network Automation? | VMware Glossary Network Automation What is network automation? Network
# An intent is a desired property of your network. An intent can describe a business policy or an arch
# An intent is a desired property of your network. An intent can describe a business policy or an arch
# An intent is a desired property of your network. An intent can describe a business policy or an arch
# An intent is a desired property of your network. An intent can describe a business policy or an arch
#
#
#
# Query: what is enterprise network
# What is Enterprise Networking? | VMware Glossary Enterprise Networking What is enterprise networking
# This checklist describes end to end requirements and configurations needed for migration with vMotio
# Specific Virtual SAN configurations, such as a stretched cluster, require a witness host. Instead of
# The virtual machines in a vApp can connect to vApp networks (isolated or routed) and organization vi
# Specific Virtual SAN configurations, such as a stretched cluster, require a witness host. Instead of
# Specific Virtual SAN configurations, such as a stretched cluster, require a witness host. Instead of
#
#
#
# Query: how to configure a nat network in vmware workstation
# Configuring a Web server on a virtual machine that uses NAT mode networking (2006955) | VMware KB Co
# Enabling Networking After VMware Workstation is Already installed (164) | VMware KB Enabling Network
# Connecting to VMware virtual machines using the Windows Remote Desktop utility (1018809) | VMware KB
# Workstation Player provides bridged networking, network address translation (NAT), and host-only net
# Workstation Player provides bridged networking, network address translation (NAT), and host-only net
# Workstation Player provides bridged networking, network address translation (NAT), and host-only net
#
#
#
# Query: what is storage area network
# What is Storage Area Network (SAN)? | VMware Glossary Storage Area Network (SAN) What is SAN and how
# If an organization virtual data center network is running out of IP addresses, you can add more addr
# If an organization virtual data center network is running out of IP addresses, you can add more addr
# What is Hyperconverged Storage? | VMware Glossary Hyperconverged Storage What is Hyperconverged Stor
# Generally, storage virtualization refers to a logical abstraction of physical storage resources and
# Generally, storage virtualization refers to a logical abstraction of physical storage resources and
#
#
#
# Query: how do servers connect to the network in a virtual environment
# What is Virtual Networking? | VMware Glossary Virtual Networking What is virtual networking? Get the
# The NAT device is connected to the VMnet8 virtual switch. Virtual machines connected to the NAT netw
# The NAT device is connected to the VMnet8 virtual switch. Virtual machines connected to the NAT netw
# The NAT device is connected to the VMnet8 virtual switch. Virtual machines connected to the NAT netw
# The NAT device is connected to the VMnet8 virtual switch. Virtual machines connected to the NAT netw
# With vSphere Replication, you can recover virtual machines that were successfully replicated at the
#
#
#
# Query: what is virtualization in networking
# What is Virtual Networking? | VMware Glossary Virtual Networking What is virtual networking? Get the
# What is Network Virtualization? | VMware Glossary Network Virtualization What is network virtualizat
# What Is Network Virtualization? | Network and Security Virtualization | VMware Post to Facebook Shar
# What is virtualization technology & virtual machine? | VMware Solutions by Category Virtualization W
# What is Virtualized Security? | VMware Glossary Virtualized Security What is virtualized security? V
# What is Desktop Virtualization? | VMware Glossary Desktop Virtualization What is Desktop Virtualizat
#
#
#
# Query: what is an enterprise network
# What is Enterprise Networking? | VMware Glossary Enterprise Networking What is enterprise networking
# This checklist describes end to end requirements and configurations needed for migration with vMotio
# The virtual machines in a vApp can connect to vApp networks (isolated or routed) and organization vi
# Specific Virtual SAN configurations, such as a stretched cluster, require a witness host. Instead of
# The virtual machines in a vApp can connect to vApp networks (isolated or routed) and organization vi
# Specific Virtual SAN configurations, such as a stretched cluster, require a witness host. Instead of
#
#
#
# Query: what is virtual networking
# What is Virtual Networking? | VMware Glossary Virtual Networking What is virtual networking? Get the
# What is Enterprise Networking? | VMware Glossary Enterprise Networking What is enterprise networking
# What is Network Virtualization? | VMware Glossary Network Virtualization What is network virtualizat
# What is Cloud Networking? | VMware Glossary Cloud Networking What is cloud networking? Cloud network
# What is Data Center Networking? | VMware Glossary Data Center Networking What is data center network
# What Is Network Virtualization? | Network and Security Virtualization | VMware Post to Facebook Shar
#
#
#
# Query: what is network convergence
# What is Network Convergence? | VMware Glossary Network Convergence What is Network Convergence? Netw
# To migrate the network traffic of distributed port groups to a LAG, you create a new LAG. Procedure
# This checklist describes end to end requirements and configurations needed for migration with vMotio
# If you deployed the management network and API access network without DHCP, you can add IP address r
# VMware SD-WAN allows an Enterprise user to monitor the events and services using a redesigned portal
# What is Converged Infrastructure? | VMware Glossary Converged Infrastructure What is Converged Infra
#
#
#
# Query: what is cloud network
# What is Cloud Networking? | VMware Glossary Cloud Networking What is cloud networking? Cloud network
# What is a Cloud Server? | VMware Glossary Cloud Server What is a cloud server? A cloud server is a p
# What is Hybrid Cloud Networking? | VMware Glossary Hybrid Cloud Networking What is a hybrid cloud ne
# The Virtual Cloud Network Introduction | Network and Security Virtualization | VMware Post to Facebo
# What is the Cloud | VMware Glossary Cloud What is the Cloud? The cloud is general term used to descr
# This checklist describes end to end requirements and configurations needed for migration with vMotio
#
#
#
# Query: what is converged network
# What is Network Convergence? | VMware Glossary Network Convergence What is Network Convergence? Netw
# What is Converged Infrastructure? | VMware Glossary Converged Infrastructure What is Converged Infra
# Advice from Real Users Who Have Transitioned to Hyper-Converged Infrastructure - VMware vSAN Virtual
# This checklist describes end to end requirements and configurations needed for migration with vMotio
# SDDC Capacity Management - Storage & Networking Aspects Share on:Share on Twitter Share on LinkedIn
# VMware allows an Enterprise user to monitor the events and services using a redesigned portal. To ac
#
#
#
# Query: what is convergence in networking
# What is Network Convergence? | VMware Glossary Network Convergence What is Network Convergence? Netw
# What is Converged Infrastructure? | VMware Glossary Converged Infrastructure What is Converged Infra
# To migrate the network traffic of distributed port groups to a LAG, you create a new LAG. Procedure
# What is Data Center Networking? | VMware Glossary Data Center Networking What is data center network
# SDDC Capacity Management - Storage & Networking Aspects Share on:Share on Twitter Share on LinkedIn
# "NFV for Dummies" blog series #1 - VMware Telco Cloud Blog Share on:Share on Twitter Share on Linked
#
#
#
# Query: what is software defined networking
# What is Software-Defined Networking (SDN)? | VMware Glossary Software-Defined Networking (SDN) What
# What is Software-Defined WAN (SD-WAN)? | VMware Glossary SD-WAN What is Software-Defined Wide Area N
# What is Software-Defined WAN (SD-WAN) and how does it work? | VMware Solutions by Category SD-WAN SD
# What is Intent-Based Networking (IBN)? | VMware Glossary Intent-based Networking What is intent-base
# VMware Validated Design for NSX-T enables IT organizations that have deployed VMware Validated Desig
# VMware Validated Design for NSX-T enables IT organizations that have deployed VMware Validated Desig
#
#
#
# Query: what is enterprise networking
# What is Enterprise Networking? | VMware Glossary Enterprise Networking What is enterprise networking
# What is Cloud Networking? | VMware Glossary Cloud Networking What is cloud networking? Cloud network
# What is Data Center Networking? | VMware Glossary Data Center Networking What is data center network
# To migrate the network traffic of distributed port groups to a LAG, you create a new LAG. Procedure
# What is Virtual Networking? | VMware Glossary Virtual Networking What is virtual networking? Get the
# What is Network Configuration? | VMware Glossary Network Configuration What is network configuration
#
#
#
# Query: the vsphere ha agent on this host cannot reach some of the management network addresses of other hosts, and ha may not be able to restart vms if a host failure occurs:
# vCenter Server 5.5 Update 1 | 11 MAR 2014 | Build 1623101  vCenter Server 5.5 Update 1 installation
# ESXi 5.x reports the HA error: HA may not be able to restart VMs if a host failure occurs (2016261)
# Unable to configure HA agents on all hosts when management network used by vCenter Server is not acc
# The vSphere HA agent on a host is in the Network Isolated state. User intervention is required to re
# The vSphere HA agent on a host is in the Network Isolated state. User intervention is required to re
# The vSphere HA agent on a host is in the Network Isolated state. User intervention is required to re
#
#
#
# Query: what is a cloud network
# What is Cloud Networking? | VMware Glossary Cloud Networking What is cloud networking? Cloud network
# What is a Cloud Server? | VMware Glossary Cloud Server What is a cloud server? A cloud server is a p
# What is the Cloud | VMware Glossary Cloud What is the Cloud? The cloud is general term used to descr
# What is Hybrid Cloud Networking? | VMware Glossary Hybrid Cloud Networking What is a hybrid cloud ne
# The Virtual Cloud Network Introduction | Network and Security Virtualization | VMware Post to Facebo
# What is Cloud Computing Infrastructure? | VMware Glossary Cloud Computing Infrastructure What is Clo
#
#
#
# Query: what is a converged network
# What is Network Convergence? | VMware Glossary Network Convergence What is Network Convergence? Netw
# What is Converged Infrastructure? | VMware Glossary Converged Infrastructure What is Converged Infra
# This checklist describes end to end requirements and configurations needed for migration with vMotio
# Advice from Real Users Who Have Transitioned to Hyper-Converged Infrastructure - VMware vSAN Virtual
# You can create an on-demand NAT network profile to define a NAT network and assign ranges of static
# To migrate the network traffic of distributed port groups to a LAG, you create a new LAG. Procedure
#
#
#
# Query: what is intent-based networking
# What is Intent-Based Networking (IBN)? | VMware Glossary Intent-based Networking What is intent-base
# What is Network Automation? | VMware Glossary Network Automation What is network automation? Network
# An intent is a desired property of your network. An intent can describe a business policy or an arch
# An intent is a desired property of your network. An intent can describe a business policy or an arch
# An intent is a desired property of your network. An intent can describe a business policy or an arch
# An intent is a desired property of your network. An intent can describe a business policy or an arch
#
#
#
# Query: the feature you are trying to use is on a network resource that is unavailable when installing
# "The feature you are trying to use is on a network resource that is unavailable" error when upgradin
# The VMware solution supports two methods of SD-WAN Edge zero-touch deployment and activation: Pull A
# The VMware solution supports two methods of SD-WAN Edge zero-touch deployment and activation: Pull A
# The VMware solution supports two methods of SD-WAN Edge zero-touch deployment and activation: Pull A
# The VMware solution supports two methods of SD-WAN Edge zero-touch deployment and activation: Pull A
# Under certain conditions, you might be unable to remove a host from the vSphere distributed switch.
#
#
#
# Query: what is micro segmentation in networking
# What is Micro-Segmentation? | VMware Glossary Micro-Segmentation What is Micro-Segmentation? Micro-s
# What is Network Segmentation? | VMware Glossary Network Segmentation What is network segmentation? N
# vRealize Suite HOL | Try Free Cloud Management Platform | VMware Products vRealize Suite Hands-on La
# How to Simplify and Accelerate Network Segmentation Post to Facebook Share on LinkedIn Share Post to
# Simplify Your Network Segmentation Implementations Post to Facebook Share on LinkedIn Share Post to
# Micro-segmentation of Applications using Application Rule Manager | Network and Security Virtualizat
#
#
#
# Query: what is the purpose of having a converged network?
# What is Network Convergence? | VMware Glossary Network Convergence What is Network Convergence? Netw
# You can create an on-demand NAT network profile to define a NAT network and assign ranges of static
# What is Converged Infrastructure? | VMware Glossary Converged Infrastructure What is Converged Infra
# This checklist describes end to end requirements and configurations needed for migration with vMotio
# SDDC Capacity Management - Storage & Networking Aspects Share on:Share on Twitter Share on LinkedIn
# After you have deployed and configured two standalone regions, you can implement NSX-T Federation to
#
#
#
# Query: what is container networking
# What is Container Networking? | VMware Glossary Container Networking What is Container Networking? C
# Network Configuration Manager network container.
# Network Configuration Manager network container.
# What is container security? | VMware Glossary Container Security What is container security? Contain
# What is Container Management? | VMware Glossary Container Management What is container management? C
# Container Networking Solutions - Microservices | VMware Solutions by Category Container Networking C
#
#
#
# Query: how does software defined networking work
# What is Software-Defined WAN (SD-WAN) and how does it work? | VMware Solutions by Category SD-WAN SD
# What is Software-Defined Networking (SDN)? | VMware Glossary Software-Defined Networking (SDN) What
# What is Software-Defined WAN (SD-WAN)? | VMware Glossary SD-WAN What is Software-Defined Wide Area N
# What is Intent-Based Networking (IBN)? | VMware Glossary Intent-based Networking What is intent-base
# VMware Validated Design for NSX-T enables IT organizations that have deployed VMware Validated Desig
# VMware Validated Design for NSX-T enables IT organizations that have deployed VMware Validated Desig
#
#
#
# Query: what is network infrastructure security
# What is Network Infrastructure Security? | VMware Glossary Network Infrastructure Security What is N
# What is Network Security? | VMware Glossary Network Security What is network security? Network secur
# What is Virtual Desktop Infrastructure Security (VDI Security)? | VMware Glossary Virtual Desktop In
# The Relevance of Network Security in an Encrypted World Post to Facebook Share on LinkedIn Share Pos
# VMware Cloud on AWS uses NSX-T to create and manage internal SDDC networks and provide endpoints for
# What is Network Access Control? | VMware Glossary Network Access Control What is network access cont
#
#
#
# Query: what is cloud in computer network
# What is Cloud Networking? | VMware Glossary Cloud Networking What is cloud networking? Cloud network
# What is a Cloud Server? | VMware Glossary Cloud Server What is a cloud server? A cloud server is a p
# What is the Cloud | VMware Glossary Cloud What is the Cloud? The cloud is general term used to descr
# What is Cloud Computing Infrastructure? | VMware Glossary Cloud Computing Infrastructure What is Clo
# What is Cloud Architecture? | VMware Glossary Cloud Architecture What is cloud architecture? Cloud a
# What is Hybrid Cloud Networking? | VMware Glossary Hybrid Cloud Networking What is a hybrid cloud ne
#
#
#
# Query: what is cloud in networking
# What is Cloud Networking? | VMware Glossary Cloud Networking What is cloud networking? Cloud network
# What is the Cloud | VMware Glossary Cloud What is the Cloud? The cloud is general term used to descr
# What is a Cloud Server? | VMware Glossary Cloud Server What is a cloud server? A cloud server is a p
# What is Cloud Computing Infrastructure? | VMware Glossary Cloud Computing Infrastructure What is Clo
# What is Enterprise Networking? | VMware Glossary Enterprise Networking What is enterprise networking
# What is Cloud Architecture? | VMware Glossary Cloud Architecture What is cloud architecture? Cloud a
#
#
#
# Query: what is network virtualization in cloud computing
# What is Network Virtualization? | VMware Glossary Network Virtualization What is network virtualizat
# What Is Network Virtualization? | Network and Security Virtualization | VMware Post to Facebook Shar
# What is Cloud Networking? | VMware Glossary Cloud Networking What is cloud networking? Cloud network
# What is Virtual Networking? | VMware Glossary Virtual Networking What is virtual networking? Get the
# The Virtual Cloud Network Introduction | Network and Security Virtualization | VMware Post to Facebo
# What is virtualization technology & virtual machine? | VMware Solutions by Category Virtualization W
#
#
#
# Query: what is san in networking
# What is Storage Area Network (SAN)? | VMware Glossary Storage Area Network (SAN) What is SAN and how
# Verify that the network infrastructure and the networking configuration on the ESXi hosts meet the m
# Verify that the network infrastructure and the networking configuration on the ESXi hosts meet the m
# Verify that the network infrastructure and the networking configuration on the ESXi hosts meet the m
# You can use Virtual SAN as the shared storage for a vSphere HA cluster. When enabled, Virtual SAN ag
# Server Manager manages Storage Area Network (SAN), which is a specialized high-speed network of stor
#
#
#
# Query: what is the core component of internet-based networking
# To migrate the network traffic of distributed port groups to a LAG, you create a new LAG. Procedure
# What is Enterprise Networking? | VMware Glossary Enterprise Networking What is enterprise networking
# If an organization virtual data center network is running out of IP addresses, you can add more addr
# If an organization virtual data center network is running out of IP addresses, you can add more addr
# This section describes the components of the Resource Pod and their functions. VNFs are placed in th
# VMware SD-WAN allows an Enterprise user to monitor the events and services using a redesigned portal
#
#
#
# Query: what is network security
# What is Network Security? | VMware Glossary Network Security What is network security? Network secur
# What is Network Infrastructure Security? | VMware Glossary Network Infrastructure Security What is N
# VMware Cloud on AWS uses NSX-T to create and manage internal SDDC networks and provide endpoints for
# What is Network Access Control? | VMware Glossary Network Access Control What is network access cont
# To migrate the network traffic of distributed port groups to a LAG, you create a new LAG. Procedure
# A security policy is a group of network and security services. The following network and security se
#
#
#
# Query: how storage area network works
# What is Storage Area Network (SAN)? | VMware Glossary Storage Area Network (SAN) What is SAN and how
# If an organization virtual data center network is running out of IP addresses, you can add more addr
# If an organization virtual data center network is running out of IP addresses, you can add more addr
# Generally, storage virtualization refers to a logical abstraction of physical storage resources and
# Generally, storage virtualization refers to a logical abstraction of physical storage resources and
# Generally, storage virtualization refers to a logical abstraction of physical storage resources and
#
#
#
# Query: what is a federated network
# What is a Federated Network? | VMware Glossary Federated Network What is a federated network? A fede
# New Federated Network Solution at HP Discover - Partner News Share on:Share on Twitter Share on Link
# OpenStack Consumption Archives - OpenStack Blog for VMware - VMware Blogs Home > Blogs > OpenStack B
# This checklist describes end to end requirements and configurations needed for migration with vMotio
# VMware Integrated OpenStack Archives - OpenStack Blog for VMware - VMware Blogs Home > Blogs > OpenS
# Provider networks map to physical networks in your data center, and their networking functions are p
#
#
#
# Query: what are virtual networks
# What is Virtual Networking? | VMware Glossary Virtual Networking What is virtual networking? Get the
# What is Network Virtualization? | VMware Glossary Network Virtualization What is network virtualizat
# The Virtual Cloud Network Introduction | Network and Security Virtualization | VMware Post to Facebo
# What Is Network Virtualization? | Network and Security Virtualization | VMware Post to Facebook Shar
# What is Enterprise Networking? | VMware Glossary Enterprise Networking What is enterprise networking
# You can configure network services, such as DHCP, firewalls, network address translation (NAT), and
#
#
#
# Query: what is network infrastructure
# What is Network Infrastructure Security? | VMware Glossary Network Infrastructure Security What is N
# To migrate the network traffic of distributed port groups to a LAG, you create a new LAG. Procedure
# Client endpoints communicate with a View Connection Server or security server host over secure conne
# Client endpoints communicate with a View Connection Server or security server host over secure conne
# What is Cloud Computing Infrastructure? | VMware Glossary Cloud Computing Infrastructure What is Clo
# What is Network Security? | VMware Glossary Network Security What is network security? Network secur
#
#
#
# Query: how to disable vmware network adapter windows 10
# In the VMware Host Client, you can add and remove VMkernel network adapters (NICs), as well as view
# In the VMware Host Client, you can add and remove VMkernel network adapters (NICs), as well as view
# In the VMware Host Client, you can add and remove VMkernel network adapters (NICs), as well as view
# How to disable Virtual machine network during offline mode (2150730) | VMware KB How to disable Virt
# Using a network adapter only with the VMware Workstation guest virtual machine (1020359) | VMware KB
# Disabling the FLEX virtual machine network is running in the offline mode (2149842) | VMware KB Disa
#
#
#
# Query: the vsphere ha agent on this host cannot reach some of the management network addresses of other hosts, and ha may not be able to restart vms if a host failure occurs
# vCenter Server 5.5 Update 1 | 11 MAR 2014 | Build 1623101  vCenter Server 5.5 Update 1 installation
# ESXi 5.x reports the HA error: HA may not be able to restart VMs if a host failure occurs (2016261)
# The vSphere HA agent on a host is in the Network Isolated state. User intervention is required to re
# The vSphere HA agent on a host is in the Network Isolated state. User intervention is required to re
# The vSphere HA agent on a host is in the Network Isolated state. User intervention is required to re
# The vSphere HA agent on a host is in the Network Isolated state. User intervention is required to re
#
#
#
# Query: how does network access control work
# What is Network Access Control? | VMware Glossary Network Access Control What is network access cont
# When Network I/O Control is enabled, the distributed switch allocates bandwidth for the traffic that
# When Network I/O Control is enabled, the distributed switch allocates bandwidth for the traffic that
# When Network I/O Control is enabled, the distributed switch allocates bandwidth for the traffic that
# When Network I/O Control is enabled, the distributed switch allocates bandwidth for the traffic that
# When Network I/O Control is enabled, the distributed switch allocates bandwidth for the traffic that
#
#
#
# Query: how to connect virtual machine to physical network
# You can add an organization virtual datacenter network to a vApp to make the network available to vi
# You can add an organization virtual datacenter network to a vApp to make the network available to vi
# You can add an organization virtual datacenter network to a vApp to make the network available to vi
# With vSphere Replication, you can recover virtual machines that were successfully replicated at the
# What is Virtual Networking? | VMware Glossary Virtual Networking What is virtual networking? Get the
# With vSphere Replication, you can recover virtual machines that were successfully replicated at the
#
#
#
# Query: how possible are the traditional separate data, telephone, and video networks be converged together into one platform?
# What is Network Convergence? | VMware Glossary Network Convergence What is Network Convergence? Netw
# VCDX-NV Interview: Greg Stemberger | Network and Security Virtualization | VMware Post to Facebook S
# How VMware NSX Secures and Simplifies M&A - VMware Industry Solutions Share on:Share on Twitter Shar
# Only A Few Days Left Until Partner Exchange @ VMworld 2016 US - VMware Tech Alliance Partners (TAP)
# Good Security Thrives in Simplicity - VMware vSphere Blog Share on:Share on Twitter Share on LinkedI
# Untangling a Mess of Meshes: What is a Service Mesh? Projects Untangling a Mess of Meshes – Part One
#
#
#
# Query: what is a network cloud
# What is Cloud Networking? | VMware Glossary Cloud Networking What is cloud networking? Cloud network
# What is the Cloud | VMware Glossary Cloud What is the Cloud? The cloud is general term used to descr
# What is a Cloud Server? | VMware Glossary Cloud Server What is a cloud server? A cloud server is a p
# A Network Without Limits: Network Edge—The New Frontier for EUC, IoT, 5G and Beyond - VMware SASE Sh
# What is Network Security? | VMware Glossary Network Security What is network security? Network secur
# If an organization virtual data center network is running out of IP addresses, you can add more addr
#
#
#
# Query: how to remove vmware network adapter
# In the VMware Host Client, you can add and remove VMkernel network adapters (NICs), as well as view
# In the VMware Host Client, you can add and remove VMkernel network adapters (NICs), as well as view
# In the VMware Host Client, you can add and remove VMkernel network adapters (NICs), as well as view
# In the VMware Host Client, you can add and remove VMkernel network adapters (NICs), as well as view
# In the VMware Host Client, you can add and remove VMkernel network adapters (NICs), as well as view
# In the VMware Host Client, you can remove a VMkernel network adapter if you no longer need it. Proce
#
#
#
# Query: what is the core component of intent-based networking
# What is Intent-Based Networking (IBN)? | VMware Glossary Intent-based Networking What is intent-base
# What is Network Automation? | VMware Glossary Network Automation What is network automation? Network
# An intent is a desired property of your network. An intent can describe a business policy or an arch
# Now Available: vRealize Network Insight 6.0! - VMware Cloud Management Share on:Share on Twitter Sha
# An intent is a desired property of your network. An intent can describe a business policy or an arch
# An intent is a desired property of your network. An intent can describe a business policy or an arch
#
#
#
# Query: what is kubernetes networking
# What is Kubernetes Networking? | VMware Glossary Kubernetes Networking What is Kubernetes networking
# Jumping into Cloud-Native Basics: A Video Series - Cloud Native Apps Blog Jumping into Cloud-Native
# vSphere 7 with Kubernetes - Shared Infrastructure Services - VMware vSphere Blog Share on:Share on T
# What is Kubernetes? | VMware Glossary Kubernetes What is Kubernetes? Kubernetes is an open-source co
# What is Enterprise Networking? | VMware Glossary Enterprise Networking What is enterprise networking
# What is Cloud Networking? | VMware Glossary Cloud Networking What is cloud networking? Cloud network
#
#
#
# Query: what is a benefit of using vsphere distributed switches in a vsan network?
# Top 5 Q&A: Getting More out of vSAN - Session 2 - VMware vSAN Virtual Blocks Blog Share on:Share on
# How is vNetwork Distributed Switch Going to Help Me? - VMware vSphere Blog Share on:Share on Twitter
# With vSphere distributed switches you can set up and configure networking in a vSphere environment.
# All three sites in a stretched cluster communicate across the management network and across the vSAN
# When performing network configuration, you have to consider the overall traffic and decide how to is
# With vSphere distributed switches you can set up and configure networking in a vSphere environment.
#
#
#
# Query: what is the maximum number of hosts per vnetwork distributed switch?
# You create and manage virtual networks on a vSphere Distributed Switch by adding hosts to the switch
# Virtual machines with vNetwork Distributed Switch lose network connectivity after HA failover (10178
# The virtual networking components in Workstation Player include virtual switches, virtual network ad
# The virtual networking components in Workstation Player include virtual switches, virtual network ad
# The virtual networking components in Workstation Player include virtual switches, virtual network ad
# The virtual networking components in Workstation Player include virtual switches, virtual network ad
#
#
#
# Query: what is configuration in networking
# What is Network Configuration? | VMware Glossary Network Configuration What is network configuration
# The latest release of Unified Access Gateway does not accept netmask or prefix and default gateway s
# The latest release of Unified Access Gateway does not accept netmask or prefix and default gateway s
# The latest release of Unified Access Gateway does not accept netmask or prefix and default gateway s
# The latest release of Unified Access Gateway does not accept netmask or prefix and default gateway s
# The latest release of Unified Access Gateway does not accept netmask or prefix and default gateway s
#
#
#
# Query: what is a san in networking
# What is Storage Area Network (SAN)? | VMware Glossary Storage Area Network (SAN) What is SAN and how
# Verify that the network infrastructure and the networking configuration on the ESXi hosts meet the m
# Verify that the network infrastructure and the networking configuration on the ESXi hosts meet the m
# Verify that the network infrastructure and the networking configuration on the ESXi hosts meet the m
# Server Manager manages Storage Area Network (SAN), which is a specialized high-speed network of stor
# Server Manager manages Storage Area Network (SAN), which is a specialized high-speed network of stor
#
#
#
# Query: what is meant by a virtual network
# What is Virtual Networking? | VMware Glossary Virtual Networking What is virtual networking? Get the
# What is Network Virtualization? | VMware Glossary Network Virtualization What is network virtualizat
# What is Enterprise Networking? | VMware Glossary Enterprise Networking What is enterprise networking
# What is Cloud Networking? | VMware Glossary Cloud Networking What is cloud networking? Cloud network
# What Is Network Virtualization? | Network and Security Virtualization | VMware Post to Facebook Shar
# The Virtual Cloud Network Introduction | Network and Security Virtualization | VMware Post to Facebo
#
#
#
# Query: what is the purpose of having a converged network
# What is Network Convergence? | VMware Glossary Network Convergence What is Network Convergence? Netw
# What is Converged Infrastructure? | VMware Glossary Converged Infrastructure What is Converged Infra
# You can create an on-demand NAT network profile to define a NAT network and assign ranges of static
# After you have deployed and configured two standalone regions, you can implement NSX-T Federation to
# To migrate the network traffic of distributed port groups to a LAG, you create a new LAG. Procedure
# Advice from Real Users Who Have Transitioned to Hyper-Converged Infrastructure - VMware vSAN Virtual

# %%
> Query: what is the maximum number of hosts per vnetwork distributed switch?

# %% [markdown]
# # Appendix

# %%
content.document_group.value_counts()

# %%
for k,v in content[content.document_group == 'docs'].iloc[0].to_dict().items():
    print(k,v)

# %%
l = list(content[content.document_group == 'docs'][content['raw_text'].notna()]['raw_text'])

# %%
lengths = sorted(list(map(len, l)))[:-100]
sum(lengths)/len(l), max(lengths), min(lengths)

# %%
import matplotlib.pyplot as plt
plt.hist(lengths[:-1000])
plt.title("histogram of number of documents with given length")
plt.xlabel("document length")
plt.ylabel("# of documents")
plt.show()

# %%
for k,v in content[content.document_group == 'blog'].iloc[100].to_dict().items():
    print(k,v)

# %%
l = list(content[content.document_group == 'blog'][content['raw_text'].notna()]['raw_text'])

# %%
lengths = sorted(list(map(len, l)))
sum(lengths)/len(l), max(lengths), min(lengths)

# %%
import matplotlib.pyplot as plt
plt.hist(lengths[:-1000])
plt.title("histogram of number of documents with given length")
plt.xlabel("document length")
plt.ylabel("# of documents")
plt.show()

# %% [markdown]
# # Queries EDA

# %%
import pandas as pd
queries = pd.read_csv("/kaggle/input/vmware-zero-shot-information-retrieval/test.csv")

# %%
queries = list(queries['Query'])
len(queries)

# %%
from random import random

# %%
for _ in range(20):
    print(queries[int(random() * len(queries))])

# %%
fqueries = filter(lambda text: ('how to' not in text) and ('what is' not in text), queries)
how_to = filter(lambda text: 'how to' in text, queries)
what_is = filter(lambda text: 'what is' in text, queries)

# %%
def stats(fqueries):
    fqueries = list(fqueries)
    print(len(fqueries), len(fqueries)/len(queries))
    for _ in range(20):
        print(fqueries[int(random() * len(fqueries) - 1)])

# %%
stats(fqueries)

# %%
stats(how_to)

# %%
stats(what_is)

# %%
sample_submission = pd.read_csv("/kaggle/input/vmware-zero-shot-information-retrieval/sample_submission.csv")

# %%
list(sample_submission['DocumentId'])[:10]
